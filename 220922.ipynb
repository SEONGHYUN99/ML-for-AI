# %% [markdown]
# <a href="https://colab.research.google.com/github/SEONGHYUN99/ML-for-AI/blob/main/220922.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/MyDrive')
# Out:
# Drive already mounted at /content/MyDrive; to attempt to forcibly remount, call drive.mount("/content/MyDrive", force_remount=True).

# %%
cd MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/
# Out:
# /content/MyDrive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition

# %%
cd ch_02
# Out:
# /content/MyDrive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02

# %%
import pandas as pd

# %%
df = pd.read_csv('data/earthquakes.csv')

# %% [markdown]
# ## Task 1

# %%
df.loc[3:10,['mag','magType']]
# Out:
#      mag magType
# 3   0.44      ml
# 4   2.16      md
# 5   2.61      md
# 6   1.70      ml
# 7   1.13      md
# 8   0.92      md
# 9   4.70      mb
# 10  0.50      ml

# %%
df.iloc[3:10,[8,9,21]]
# Out:
#     mag magType        type
# 3  0.44      ml  earthquake
# 4  2.16      md  earthquake
# 5  2.61      md  earthquake
# 6  1.70      ml  earthquake
# 7  1.13      md  earthquake
# 8  0.92      md  earthquake
# 9  4.70      mb  earthquake

# %%
df.loc[(df.title.str.contains('Arizona'))]
# Out:
#      alert  cdi      code                                             detail  \
# 1062   NaN  NaN  60300227  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3965   NaN  NaN  60298572  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#         dmin  felt    gap           ids   mag magType  ...  sources    status  \
# 1062  0.1666   NaN  163.0  ,uu60300227,  1.23      ml  ...     ,uu,  reviewed
# 3965  0.1577   NaN  211.0  ,uu60298572,  0.94      md  ...     ,uu,  reviewed
#
#                time                                      title  tsunami  \
# 1062  1539133978610  M 1.2 - 7km SSW of Colorado City, Arizona        0
# 3965  1538383710020  M 0.9 - 7km WSW of Colorado City, Arizona        0
#
#             type                         types     tz        updated  \
# 1062  earthquake  ,geoserve,origin,phase-data, -420.0  1539196068710
# 3965  earthquake  ,geoserve,origin,phase-data, -420.0  1538516934720
#
#                                                     url
# ...

# %%
df.nlargest(n=10,columns='mag')
# Out:
#       alert  cdi      code                                             detail  \
# 5263    red  8.4  1000h3p4  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 837   green  4.1  1000haa3  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 118   green  NaN  1000hbkz  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4363  green  2.2  1000h4l1  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 799   green  NaN  1000hacw  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 816   green  NaN  1000habl  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 838   green  NaN  1000ha9t  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 5323  green  NaN  1000h3mf  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 862   green  4.3  1000ha6q  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1267  green  NaN  1000h97j  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin   felt   gap                                 ids  mag magType  \
# ...

# %% [markdown]
# ## Task 2

# %%
df.drop(columns='alert')
# Out:
#       cdi        code                                             detail  \
# 0     NaN    37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1     NaN    37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2     4.4    37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3     NaN    37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4     NaN    73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
# ...   ...         ...                                                ...
# 9327  NaN    73086771  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9328  NaN    38063967  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9329  NaN  2018261000  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9330  NaN    38063959  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9331  NaN    38063935  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#           dmin  felt    gap             ids   mag magType  mmi  ... sources  \
# ...

# %%
mag=df.pop('mag')
magType=df.pop('magType')

# %%
new=pd.concat([mag,magType],axis=1)

# %%
new
# Out:
#        mag magType
# 0     1.35      ml
# 1     1.29      ml
# 2     3.42      ml
# 3     0.44      ml
# 4     2.16      md
# ...    ...     ...
# 9327  0.62      md
# 9328  1.00      ml
# 9329  2.40      md
# 9330  1.10      ml
# 9331  0.66      ml
#
# [9332 rows x 2 columns]

# %% [markdown]
# Practice

# %%
cd /content/MyDrive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/
# Out:
# /content/MyDrive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition

# %%
cd ch_03
# Out:
# /content/MyDrive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_03

# %%
df = pd.read_csv('data/nyc_temperatures.csv')

# %%
df.head()
# Out:
#                   date datatype            station attributes  value
# 0  2018-10-01T00:00:00     TAVG  GHCND:USW00014732      H,,S,   21.2
# 1  2018-10-01T00:00:00     TMAX  GHCND:USW00014732   ,,W,2400   25.6
# 2  2018-10-01T00:00:00     TMIN  GHCND:USW00014732   ,,W,2400   18.3
# 3  2018-10-02T00:00:00     TAVG  GHCND:USW00014732      H,,S,   22.7
# 4  2018-10-02T00:00:00     TMAX  GHCND:USW00014732   ,,W,2400   26.1

# %%
#renaming columns 
df.columns
# Out:
# Index(['date', 'datatype', 'station', 'attributes', 'value'], dtype='object')

# %%
df.rename(
    columns={
        'value': 'temp_C',
        'attributes': 'flags'
    }, inplace=True
)

# %%
df.columns
# Out:
# Index(['date', 'datatype', 'station', 'flags', 'temp_C'], dtype='object')

# %%
df.head()
# Out:
#                   date datatype            station     flags  temp_C
# 0  2018-10-01T00:00:00     TAVG  GHCND:USW00014732     H,,S,    21.2
# 1  2018-10-01T00:00:00     TMAX  GHCND:USW00014732  ,,W,2400    25.6
# 2  2018-10-01T00:00:00     TMIN  GHCND:USW00014732  ,,W,2400    18.3
# 3  2018-10-02T00:00:00     TAVG  GHCND:USW00014732     H,,S,    22.7
# 4  2018-10-02T00:00:00     TMAX  GHCND:USW00014732  ,,W,2400    26.1

# %%
df.rename(str.upper, axis='columns').columns
# Out:
# Index(['DATE', 'DATATYPE', 'STATION', 'FLAGS', 'TEMP_C'], dtype='object')

# %%
#Type conversion
df.dtypes
# Out:
# date         object
# datatype     object
# station      object
# flags        object
# temp_C      float64
# dtype: object

# %%
df.loc[:,'date']
# Out:
# 0     2018-10-01T00:00:00
# 1     2018-10-01T00:00:00
# 2     2018-10-01T00:00:00
# 3     2018-10-02T00:00:00
# 4     2018-10-02T00:00:00
#              ...
# 88    2018-10-30T00:00:00
# 89    2018-10-30T00:00:00
# 90    2018-10-31T00:00:00
# 91    2018-10-31T00:00:00
# 92    2018-10-31T00:00:00
# Name: date, Length: 93, dtype: object

# %%
df.loc[:,'date']=pd.to_datetime(df.date)

# %%
df.loc[:,'date']=pd.to_datetime(df.date)

# %%
df.dtypes
# Out:
# date          datetime64[ns]
# datatype              object
# station               object
# attributes            object
# value                float64
# dtype: object

# %%
df.date.describe(datetime_is_numeric=True)
# Out:
# count                     93
# mean     2018-10-16 00:00:00
# min      2018-10-01 00:00:00
# 25%      2018-10-08 00:00:00
# 50%      2018-10-16 00:00:00
# 75%      2018-10-24 00:00:00
# max      2018-10-31 00:00:00
# Name: date, dtype: object

# %%
pd.date_range(start='2018-10-25',periods=2,freq='D')
# Out:
# DatetimeIndex(['2018-10-25', '2018-10-26'], dtype='datetime64[ns]', freq='D')

# %%
df.head()
# Out:
#         date datatype            station attributes  value
# 0 2018-10-01     TAVG  GHCND:USW00014732      H,,S,   21.2
# 1 2018-10-01     TMAX  GHCND:USW00014732   ,,W,2400   25.6
# 2 2018-10-01     TMIN  GHCND:USW00014732   ,,W,2400   18.3
# 3 2018-10-02     TAVG  GHCND:USW00014732      H,,S,   22.7
# 4 2018-10-02     TMAX  GHCND:USW00014732   ,,W,2400   26.1

# %%
eastern=pd.read_csv('data/nyc_temperatures.csv',index_col='date',parse_dates=True).tz_localize('EST')

# %%
cd /content/MyDrive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02
# Out:
# /content/MyDrive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02

# %%
df = pd.read_csv(
    'data/earthquakes.csv', 
    usecols=['time', 'title', 'place', 'magType', 'mag', 'alert', 'tsunami']
)

# %%
df.place.str.extract(r', (.*$)')
# Out:
#                 0
# 0              CA
# 1              CA
# 2              CA
# 3              CA
# 4              CA
# ...           ...
# 9327           CA
# 9328           CA
# 9329  Puerto Rico
# 9330           CA
# 9331           CA
#
# [9332 rows x 1 columns]
